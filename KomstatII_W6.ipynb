# %% [markdown]
# # Komputasi Statistika II | 31st Mar 2026
#
# ## Analisis Diskriminan

# %%
from IPython.display import Image, display
display(Image('1.png'))
print(' ')
display(Image('2.png'))

# %%
display(Image('3.png'))
print(' ')
display(Image('4.png'))
print(' ')
display(Image('5.png'))

# %%
display(Image('6.png'))
print(' ')
display(Image('7.png'))
print(' ')
display(Image('8.png'))

# %%
display(Image('9.png'))
display(Image('10.png'))

# %%
display(Image('11.png'))
display(Image('12.png'))
display(Image('13.png'))
